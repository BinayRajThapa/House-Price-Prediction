# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    Unnamed: 0                    TITLE                LOCATION         PRICE  \
# 0           0           House for Sale        Imadol, Lalitpur   Rs. 2.9 Cr
# 1           1           House for Sale     Satdobato, Lalitpur  Rs. 4.75 Cr
# 2           2     4 BHK House for Sale        Imadol, Lalitpur  Rs. 1.99 Cr
# 3           3  Bungalow House for Sale    Bhaisepati, Lalitpur     Rs. 4 Cr
# 4           4           House for Rent  Maharajgunj, Kathmandu  Rs. 12000000
#
#   LAND AREA ROAD ACCESS      FACING  FLOOR  BEDROOM  BATHROOM BUILT YEAR  \
# 0  4.0 aana     12 Feet        West    3.0      5.0       4.0   2076 B.S
# 1  3.0 aana     10 Feet        West    4.5      5.0       6.0   2076 B.S
# 2  2.3 aana     10 Feet        West    2.5      4.0       4.0   2060 B.S
# 3  7.0 aana     12 Feet  North-West    2.5      4.0       3.0   2059 B.S
# 4  6.0 aana     20 Feet       South    2.0      4.0       4.0   2071 B.S
#
# ...
